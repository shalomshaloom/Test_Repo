# %% [markdown]
# # Commit to Github

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PROJ_path = "/content/drive/MyDrive/ColabNotebooks/Test_Repo"
# %cd "{PROJ_path}"
# %pwd
# Out:
# /content/drive/MyDrive/ColabNotebooks/Test_Repo
# '/content/drive/MyDrive/ColabNotebooks/Test_Repo'

# %%
! git config --global user.email "cwseok99@gmail.com"
! git config --global user.name "shalomshaloom"

# %%
! git status

# %%
! git
! git commit -m "원하는 아무 메세지"
! git push
